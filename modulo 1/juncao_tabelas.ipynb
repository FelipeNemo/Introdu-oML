# %%
import pandas as pd

# %%
voos = pd.read_csv('../data/aulas/juncao_tabelas/voos.csv', delimiter= ";")
voos.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
qnt_voos = pd.read_csv('../data/aulas/juncao_tabelas/quatidade_de_voos.csv', delimiter= ";")
qnt_voos.tail()
# Out:
#    month  qnt
# 7    Aug  386
# 8    Sep  396
# 9    Oct  376
# 10   Nov  262
# 11   Dec  436

# %%
pd.merge(voos, qnt_voos, on='month') # merge em month
# Out:
#      year month  passengers  qnt
# 0    1949   Jan         112  284
# 1    1950   Jan         115  284
# 2    1951   Jan         145  284
# 3    1952   Jan         171  284
# 4    1953   Jan         196  284
# ..    ...   ...         ...  ...
# 139  1956   Dec         306  436
# 140  1957   Dec         336  436
# 141  1958   Dec         337  436
# 142  1959   Dec         405  436
# 143  1960   Dec         432  436
#
# [144 rows x 4 columns]

# %%
produtos1 = pd.read_csv('../data/aulas/juncao_tabelas/produtos1.csv', delimiter= ";", index_col=['id']) # O id será o index da tabela(linhas)
produtos1.head()
# Out:
#               nome preco
# id
# 1         sabonete   5,4
# 2   pasta de dente   7,9
# 3      desodorante  15,4

# %%
produtos2 = pd.read_csv('../data/aulas/juncao_tabelas/produtos2.csv', delimiter= ";", index_col=['id'])
produtos2.head()
# Out:
#                 nome preco
# id
# 4   escova de dentes  34,2
# 5          amaciante  37,8
# 6      condicionador  12,9

# %%
produtos = pd.concat([produtos1, produtos2]) # colocou uma embaixo da outra
produtos.head()
# Out:
#                 nome preco
# id
# 1           sabonete   5,4
# 2     pasta de dente   7,9
# 3        desodorante  15,4
# 4   escova de dentes  34,2
# 5          amaciante  37,8

# %%
vendas = pd.read_csv('../data/aulas/juncao_tabelas/vendas.csv', delimiter= ";")
vendas.head()
# Out:
#          data  quantidade  produto_id
# 0  01/01/2022          10           1
# 1  02/01/2022           5           2
# 2  03/01/2022           7           1
# 3  04/01/2022          12           3

# %%
vendas = vendas.join(produtos, on='produto_id') # o produto_id e o nome do produto na mesma coluna, o preço do sabonete equivale ao preço do sabonete não a quantidade total
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 vendas = vendas.join(produtos, on='produto_id') # o produto_id e o nome do produto na mesma coluna, o preço do sabonete equivale ao preço do sabonete não a quantidade total
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:9729, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9566 def join(
#    9567     self,
#    9568     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9574     validate: str | None = None,
#    9575 ) -> DataFrame:
#    9576     """
#    9577     Join columns of another DataFrame.
#    9578
#    (...)
#    9727     5  K1  A5   B1
#    9728     """
# -> 9729     return self._join_compat(
#    9730         other,
#    9731         on=on,
#    9732         how=how,
#    9733         lsuffix=lsuffix,
# ...

# %%
vendas.head()
# Out:
#          data  quantidade  produto_id            nome preco
# 0  01/01/2022          10           1        sabonete   5,4
# 1  02/01/2022           5           2  pasta de dente   7,9
# 2  03/01/2022           7           1        sabonete   5,4
# 3  04/01/2022          12           3     desodorante  15,4

# %%
vendas['total'] = vendas.quantidade * vendas.preco # operações com colunas inteiras

# %%
vendas.head()
# Out:
#          data  quantidade  produto_id            nome preco  \
# 0  01/01/2022          10           1        sabonete   5,4
# 1  02/01/2022           5           2  pasta de dente   7,9
# 2  03/01/2022           7           1        sabonete   5,4
# 3  04/01/2022          12           3     desodorante  15,4
#
#                                               total
# 0                    5,45,45,45,45,45,45,45,45,45,4
# 1                                   7,97,97,97,97,9
# 2                             5,45,45,45,45,45,45,4
# 3  15,415,415,415,415,415,415,415,415,415,415,415,4

# %%
print(type(vendas['total']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Garantir que as colunas quantidade e preco sejam numéricas
vendas['quantidade'] = pd.to_numeric(vendas['quantidade'], errors='coerce')
vendas['preco'] = pd.to_numeric(vendas['preco'], errors='coerce')

# Criar a coluna total multiplicando quantidade por preco
vendas['total'] = vendas['quantidade'] * vendas['preco']

# Exibir o resultado
print(vendas)
# Out:
#          data  quantidade  produto_id            nome  preco  total
# 0  01/01/2022          10           1        sabonete    NaN    NaN
# 1  02/01/2022           5           2  pasta de dente    NaN    NaN
# 2  03/01/2022           7           1        sabonete    NaN    NaN
# 3  04/01/2022          12           3     desodorante    NaN    NaN
